# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/data/googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include = "all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (10358, 13)

# %%
df.reset_index(inplace = True)

# %%
df[~df["Reviews"].str.isnumeric()]
# Out:
#       index                                      App Category  Rating Reviews  \
# 9990  10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df.drop(9990,inplace = True)

# %%
df.shape
# Out:
# (10357, 14)

# %%
df
# Out:
#        index                                                App  \
# 0          0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1          1                                Coloring book moana
# 2          2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3          3                              Sketch - Draw & Paint
# 4          4              Pixel Draw - Number Art Coloring Book
# ...      ...                                                ...
# 10353  10836                                   Sya9a Maroc - FR
# 10354  10837                   Fr. Mike Schmitz Audio Teachings
# 10355  10838                             Parkinson Exercices FR
# 10356  10839                      The SCP Foundation DB fr nn5n
# 10357  10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating Reviews                Size     Installs  \
# 0           ART_AND_DESIGN     4.1     159                 19M      10,000+
# ...

# %%
df.Reviews.dtype
# Out:
# dtype('O')

# %%
df['Reviews']=df['Reviews'].astype(int)

# %%
df.Reviews.dtype
# Out:
# dtype('int64')

# %%
df.Size
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10353                   53M
# 10354                  3.6M
# 10355                  9.5M
# 10356    Varies with device
# 10357                   19M
# Name: Size, Length: 10357, dtype: object

# %%
df.Size = df.Size.str.replace('M','000')

# %%
df.Size = df.Size.str.replace('k','')

# %%
import numpy as np
df.Size.dtype
# Out:
# dtype('O')

# %%
df.Size = df.Size.str.replace('Varies with device',str(np.nan))

# %%
df.Size.dtype
# Out:
# dtype('O')

# %%
df.Size = df.Size.astype(float)

# %%
df.Size
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10353    53000.0
# 10354        3.6
# 10355        9.5
# 10356        NaN
# 10357    19000.0
# Name: Size, Length: 10357, dtype: float64

# %%
df.Installs
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10353         5,000+
# 10354           100+
# 10355         1,000+
# 10356         1,000+
# 10357    10,000,000+
# Name: Installs, Length: 10357, dtype: object

# %%
df.Installs = df.Installs.str.replace("+","").str.replace(",","")
# Out:
# <ipython-input-30-63697283b64a>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.Installs = df.Installs.str.replace("+","").str.replace(",","")

# %%
df.head()
# Out:
#    index                                                App        Category  \
# 0      0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1      1                                Coloring book moana  ART_AND_DESIGN
# 2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3      3                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4      4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Rating  Reviews     Size  Installs  Type Price Content Rating  \
# 0     4.1      159  19000.0     10000  Free     0       Everyone
# 1     3.9      967  14000.0    500000  Free     0       Everyone
# 2     4.7    87510      8.7   5000000  Free     0       Everyone
# 3     4.5   215644  25000.0  50000000  Free     0           Teen
# 4     4.3      967      2.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df.Installs.dtype
# Out:
# dtype('O')

# %%
df.Installs = df.Installs.astype(int)

# %%
df.Installs.dtype
# Out:
# dtype('int64')

# %%
df.Type.unique()
# Out:
# array(['Free', 'Paid', nan], dtype=object)

# %%
df.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df.Price = df.Price.str.replace("$",'')
# Out:
# <ipython-input-40-d3f487d5f029>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.Price = df.Price.str.replace("$",'')

# %%
df.Price = df.Price.astype(float)

# %%
categorical_column = [i for i in df.columns if df[i].dtype == 'O']

# %%
numerical_column = [i for i in df.columns if df[i].dtype != 'O']

# %%
categorical_column
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
numerical_column
# Out:
# ['index', 'Rating', 'Reviews', 'Size', 'Installs', 'Price']

# %%
df.head()
# Out:
#    index                                                App        Category  \
# 0      0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1      1                                Coloring book moana  ART_AND_DESIGN
# 2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3      3                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4      4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 0     4.1      159  19000.0     10000  Free    0.0       Everyone
# 1     3.9      967  14000.0    500000  Free    0.0       Everyone
# 2     4.7    87510      8.7   5000000  Free    0.0       Everyone
# 3     4.5   215644  25000.0  50000000  Free    0.0           Teen
# 4     4.3      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df.Type.value_counts()
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %%
df.Type.value_counts(normalize = True)
# Out:
# Free    0.92613
# Paid    0.07387
# Name: Type, dtype: float64

# %%
import seaborn as sns
sns.countplot(x=df.Type)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
df.head()
# Out:
#    index                                                App        Category  \
# 0      0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1      1                                Coloring book moana  ART_AND_DESIGN
# 2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3      3                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4      4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 0     4.1      159  19000.0     10000  Free    0.0       Everyone
# 1     3.9      967  14000.0    500000  Free    0.0       Everyone
# 2     4.7    87510      8.7   5000000  Free    0.0       Everyone
# 3     4.5   215644  25000.0  50000000  Free    0.0           Teen
# 4     4.3      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
sns.histplot(df.Rating)
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.kdeplot(df.Rating)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df.Rating)
# Out:
# <ipython-input-67-2983667e9170>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Rating)
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df.Category.value_counts(normalize = True)
# Out:
# FAMILY                 0.187603
# GAME                   0.108236
# TOOLS                  0.081394
# BUSINESS               0.041228
# MEDICAL                0.039394
# PRODUCTIVITY           0.039297
# PERSONALIZATION        0.037463
# LIFESTYLE              0.036014
# COMMUNICATION          0.035338
# FINANCE                0.034759
# SPORTS                 0.033890
# PHOTOGRAPHY            0.031090
# HEALTH_AND_FITNESS     0.029545
# SOCIAL                 0.027035
# NEWS_AND_MAGAZINES     0.025490
# TRAVEL_AND_LOCAL       0.022883
# BOOKS_AND_REFERENCE    0.022207
# SHOPPING               0.021628
# DATING                 0.018924
# VIDEO_PLAYERS          0.016897
# MAPS_AND_NAVIGATION    0.013228
# EDUCATION              0.012552
# FOOD_AND_DRINK         0.011973
# ENTERTAINMENT          0.010717
# AUTO_AND_VEHICLES      0.008207
# LIBRARIES_AND_DEMO     0.008207
# WEATHER                0.007917
# HOUSE_AND_HOME         0.007724
# ART_AND_DESIGN         0.006276
# ...

# %%
df.Category.value_counts().plot.pie(autopct = "%1.1f%%",figsize = (12,12))
# Out:
# <Axes: ylabel='Category'>

# %%
df.Category.value_counts()[:10]
# Out:
# FAMILY             1943
# GAME               1121
# TOOLS               843
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     388
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: Category, dtype: int64

# %%
df.groupby(df.Category).Installs.sum().sort_values(ascending = False).reset_index()
# Out:
#                Category     Installs
# 0                  GAME  31544024415
# 1         COMMUNICATION  24152276251
# 2                SOCIAL  12513867902
# 3          PRODUCTIVITY  12463091369
# 4                 TOOLS  11452771915
# 5                FAMILY  10041692505
# 6           PHOTOGRAPHY   9721247655
# 7      TRAVEL_AND_LOCAL   6361887146
# 8         VIDEO_PLAYERS   6222002720
# 9    NEWS_AND_MAGAZINES   5393217760
# 10             SHOPPING   2573348785
# 11        ENTERTAINMENT   2455660000
# 12      PERSONALIZATION   2074494782
# 13  BOOKS_AND_REFERENCE   1916469576
# 14               SPORTS   1528574498
# 15   HEALTH_AND_FITNESS   1361022512
# 16             BUSINESS    863664865
# 17              FINANCE    770348734
# 18  MAPS_AND_NAVIGATION    724281890
# 19            LIFESTYLE    534823539
# 20            EDUCATION    533952000
# 21              WEATHER    426100520
# 22       FOOD_AND_DRINK    257898751
# 23               DATING    206536107
# ...

# %%
df.head()
# Out:
#    index                                                App        Category  \
# 0      0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1      1                                Coloring book moana  ART_AND_DESIGN
# 2      2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3      3                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4      4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 0     4.1      159  19000.0     10000  Free    0.0       Everyone
# 1     3.9      967  14000.0    500000  Free    0.0       Everyone
# 2     4.7    87510      8.7   5000000  Free    0.0       Everyone
# 3     4.5   215644  25000.0  50000000  Free    0.0           Teen
# 4     4.3      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df.groupby([df.Category,df.Type]).Installs.sum().sort_values(ascending = False).reset_index()
# Out:
#               Category  Type     Installs
# 0                 GAME  Free  31522924450
# 1        COMMUNICATION  Free  24150916201
# 2               SOCIAL  Free  12513861902
# 3         PRODUCTIVITY  Free  12461679314
# 4                TOOLS  Free  11451044474
# ..                 ...   ...          ...
# 58            SHOPPING  Paid        10100
# 59              SOCIAL  Paid         6000
# 60  NEWS_AND_MAGAZINES  Paid         5500
# 61  LIBRARIES_AND_DEMO  Paid          100
# 62              EVENTS  Paid            1
#
# [63 rows x 3 columns]

# %%
df.groupby([df.Category,df.Type]).Installs.sum()
# Out:
# Category           Type
# ART_AND_DESIGN     Free     124322100
#                    Paid         16000
# AUTO_AND_VEHICLES  Free      53080061
#                    Paid         50150
# BEAUTY             Free      27197050
#                               ...
# TRAVEL_AND_LOCAL   Paid        183060
# VIDEO_PLAYERS      Free    6221931720
#                    Paid         71000
# WEATHER            Free     425288520
#                    Paid        812000
# Name: Installs, Length: 63, dtype: int64

# %%
df.groupby([df.Category,df.App]).Installs.sum().sort_values(ascending = False).reset_index()
# Out:
#                 Category                           App    Installs
# 0                   GAME                Subway Surfers  5000000000
# 1            PHOTOGRAPHY                 Google Photos  4000000000
# 2          COMMUNICATION                      Hangouts  4000000000
# 3       TRAVEL_AND_LOCAL     Maps - Navigate & Explore  3000000000
# 4          COMMUNICATION  Google Chrome: Fast & Secure  3000000000
# ...                  ...                           ...         ...
# 9739        PRODUCTIVITY                 cronometra-br           0
# 9740              FAMILY     Command & Conquer: Rivals           0
# 9741  NEWS_AND_MAGAZINES             Sweden Newspapers           0
# 9742              SOCIAL       Ak Parti Yardım Toplama           0
# 9743             MEDICAL                  EP Cook Book           0
#
# [9744 rows x 3 columns]

# %%
df.groupby([df.App]).Installs.sum().sort_values(ascending = False).reset_index()
# Out:
#                                     App    Installs
# 0                        Subway Surfers  5000000000
# 1                         Google Photos  4000000000
# 2                              Hangouts  4000000000
# 3                           Google News  3000000000
# 4          Google Chrome: Fast & Secure  3000000000
# ...                                 ...         ...
# 9654          Command & Conquer: Rivals           0
# 9655             Test Application DT 02           0
# 9656             AP Series Solution Pro           0
# 9657  I'm Rich/Eu sou Rico/أنا غني/我很有錢           0
# 9658            Ak Parti Yardım Toplama           0
#
# [9659 rows x 2 columns]
